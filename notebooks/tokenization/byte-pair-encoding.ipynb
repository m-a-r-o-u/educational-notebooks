# %% [markdown]
# # Byte Pair Encoding
#
# **Description:** Learn how Byte Pair Encoding builds a vocabulary by repeatedly merging frequent symbol pairs.
#
# **Level:** Beginner
# **Tags:** NLP, Tokenization

# %%
words = ["low", "lower", "newest", "widest"]
words
